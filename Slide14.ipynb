# %%
import pandas as pd

# %%
#EU consumption
df=pd.read_csv('nama_10_co3_p3_1_Data.csv')
df
# Out:
#        TIME                                                GEO  \
# 0      2009          European Union - 27 countries (from 2019)
# 1      2009          European Union - 27 countries (from 2019)
# 2      2009          European Union - 27 countries (from 2019)
# 3      2009          European Union - 27 countries (from 2019)
# 4      2009          European Union - 27 countries (from 2019)
# 5      2009          European Union - 27 countries (from 2019)
# 6      2009          European Union - 27 countries (from 2019)
# 7      2009          European Union - 27 countries (from 2019)
# 8      2009          European Union - 27 countries (from 2019)
# 9      2009          European Union - 27 countries (from 2019)
# 10     2009          European Union - 27 countries (from 2019)
# 11     2009          European Union - 27 countries (from 2019)
# 12     2009          European Union - 27 countries (from 2019)
# 13     2009          European Union - 27 countries (from 2019)
# ...

# %%
df1=df[(df.GEO=='European Union - 28 countries')&(df.TIME==2017)]
df1
# Out:
#        TIME                            GEO  \
# 42090  2017  European Union - 28 countries
# 42091  2017  European Union - 28 countries
# 42092  2017  European Union - 28 countries
# 42093  2017  European Union - 28 countries
# 42094  2017  European Union - 28 countries
# 42095  2017  European Union - 28 countries
# 42096  2017  European Union - 28 countries
# 42097  2017  European Union - 28 countries
# 42098  2017  European Union - 28 countries
# 42099  2017  European Union - 28 countries
# 42100  2017  European Union - 28 countries
# 42101  2017  European Union - 28 countries
# 42102  2017  European Union - 28 countries
# 42103  2017  European Union - 28 countries
# 42104  2017  European Union - 28 countries
# 42105  2017  European Union - 28 countries
# 42106  2017  European Union - 28 countries
# 42107  2017  European Union - 28 countries
# 42108  2017  European Union - 28 countries
# 42109  2017  European Union - 28 countries
# 42110  2017  European Union - 28 countries
# ...

# %%
df1.to_excel('EU_consumption.xlsx')
