# %% [markdown]
# Этот файл загружает файлы с файлового хранилища Государственной казначейской службы.
# Меняем названия столбцов и все.

# %%
import pandas as pd
import numpy as np
#изменить опцию inf было важно при импорте группировок
pd.options.mode.use_inf_as_na = True
pd.set_option('display.float_format', lambda x: '%.2f' % x)# very useful

# %% [markdown]
# https://www.treasury.gov.ua/ua/file-storage/vikonannya-derzhavnogo-byudzhetu
# Розділ ІІ.1. Видатки за програмною класифікацією видатків та кредитування державного бюджету

# %%
df2013=pd.read_excel('https://www.treasury.gov.ua/storage/app/uploads/public/5c0/e3d/fc5/5c0e3dfc53384419718568.xls',skiprows=7,dtype={'1':str})
# меняем названия столбцов на удобные
# они приблизительно одинаковые во всех годах, но нужно быть внимательным
col2013=['code','name','zf_zatv','zf_plan','zf_ass','zf_napr','zf_done','sf_zatv','sf_plan','sf_done','all_zatv','all_plan','all_done','end']
df2013.columns=col2013

# %%
df2014=pd.read_excel('https://www.treasury.gov.ua/storage/app/uploads/public/5c0/e3d/e30/5c0e3de307dbf315205926.xls',skiprows=7,dtype={'1':str})
df2014.head()
col2014=['code','name','zf_zatv','zf_plan','zf_ass','zf_napr','zf_done','sf_zatv','sf_plan','sf_done','all_zatv','all_plan','all_done']
df2014.columns=col2014

# %%
df2015=pd.read_excel('https://www.treasury.gov.ua/storage/app/uploads/public/5c0/e3d/c3e/5c0e3dc3e3242989489272.xls',skiprows=7,dtype={'1':str})
df2015.head()
col2015=['code','name','zf_zatv','zf_plan','zf_ass','zf_napr','zf_done','sf_zatv','sf_plan','sf_done','all_zatv','all_plan','all_done']
df2015.columns=col2015

# %%
df2016=pd.read_excel('https://www.treasury.gov.ua/storage/app/uploads/public/5c0/e3d/a03/5c0e3da030438591776123.xls',skiprows=7,dtype={'1':str})
df2016.head()
col2016=['code','name','zf_zatv','zf_plan','zf_ass','zf_napr','zf_done','sf_zatv','sf_plan','sf_done','all_zatv','all_plan','all_done']
df2016.columns=col2016

# %%
df2017=pd.read_excel('https://www.treasury.gov.ua/storage/app/uploads/public/5c0/e3d/81c/5c0e3d81cbd3b533936390.xls',skiprows=7,dtype={'1':str})
col2017=['code','name','zf_zatv','zf_plan','zf_pl1_9','zf_ass','zf_napr','zf_done','sf_zatv','sf_plan','sf_done','all_zatv','all_plan','all_done']
df2017.columns=col2017
df2017.head()
# в 2017,2018 году появился новый параметр-столбцов на один больше
# Out:
#       code                                               name       zf_zatv  \
# 0  0110000                      Апарат Верховної Ради України 1217028900.00
# 1  0111000                      Апарат Верховної Ради України 1217028900.00
# 2  0111010  Здійснення законотворчої діяльності Верховної ...  625216300.00
# 3  0111020  Обслуговування та організаційне, інформаційно-...  532300700.00
# 4  0111090  Висвітлення діяльності  Верховної  Ради  Украї...   59511900.00
#
#         zf_plan      zf_pl1_9        zf_ass       zf_napr       zf_done  \
# 0 1227028900.00 1227028900.00 1227028900.00 1227028900.00 1126190959.55
# 1 1227028900.00 1227028900.00           nan 1227028900.00 1126190959.55
# 2  625216300.00  625216300.00           nan  625216300.00  542394558.08
# 3  532300700.00  532300700.00           nan  532300700.00  518200867.00
# 4   59511900.00   59511900.00           nan   59511900.00   55656741.66
#
# ...

# %%
df2018=pd.read_excel('https://www.treasury.gov.ua/storage/app/uploads/public/5c9/df3/be2/5c9df3be25b13686386008.xlsx',skiprows=7,dtype={'1':str})
col2018=['code','name','zf_zatv','zf_plan','zf_pl1_9','zf_ass','zf_napr','zf_done','sf_zatv','sf_plan','sf_done','all_zatv','all_plan','all_done']
df2018.columns=col2018
df2018.head()
# Out:
#       code                                               name       zf_zatv  \
# 0  0110000                      Апарат Верховної Ради України 1724286200.00
# 1  0111000                      Апарат Верховної Ради України 1724286200.00
# 2  0111010  Здійснення законотворчої діяльності Верховної ...  897066500.00
# 3  0111020  Обслуговування та організаційне, інформаційно-...  765668800.00
# 4  0111090  Висвітлення діяльності Верховної Ради України ...   61550900.00
#
#         zf_plan      zf_pl1_9        zf_ass       zf_napr       zf_done  \
# 0 1724286200.00 1724286200.00 1724286200.00 1710173300.00 1664714210.77
# 1 1724286200.00 1724286200.00           nan 1710173300.00 1664714210.77
# 2  897066500.00  897066500.00           nan  882953600.00  844162126.18
# 3  765668800.00  765668800.00           nan  765668800.00  759027972.37
# 4   61550900.00   61550900.00           nan   61550900.00   61524112.22
#
# ...
