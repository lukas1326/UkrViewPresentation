# %% [markdown]
# # Обновление таблицы Демографічні параметри населення України у 2010-2050 роках.

# %%
import pandas as pd

# %%
df=pd.read_csv("https://population.un.org/wpp/DVD/Files/1_Indicators%20(Standard)/CSV_FILES/WPP2017_TotalPopulationBySex.csv")

# %%
df[(df.Location=='Ukraine')&(df.Variant=='Constant fertility')]
# Out:
#         LocID Location  VarID             Variant  Time  MidPeriod    PopMale  \
# 161721    804  Ukraine      5  Constant fertility  1950     1950.5  16008.781
# 161722    804  Ukraine      5  Constant fertility  1951     1951.5  16292.454
# 161723    804  Ukraine      5  Constant fertility  1952     1952.5  16590.515
# 161724    804  Ukraine      5  Constant fertility  1953     1953.5  16897.301
# 161725    804  Ukraine      5  Constant fertility  1954     1954.5  17208.207
# 161726    804  Ukraine      5  Constant fertility  1955     1955.5  17519.665
# 161727    804  Ukraine      5  Constant fertility  1956     1956.5  17829.212
# 161728    804  Ukraine      5  Constant fertility  1957     1957.5  18135.435
# 161729    804  Ukraine      5  Constant fertility  1958     1958.5  18437.843
# 161730    804  Ukraine      5  Constant fertility  1959     1959.5  18736.604
# 161731    804  Ukraine      5  Constant fertility  1960     1960.5  19031.948
# ...

# %% [markdown]
# **Probabilistic projection of total population (both sexes combined) by region, subregion, country or area, 2015-2100 (thousands) **[Link for all downloads](https://population.un.org/wpp/Download/Probabilistic/Population/)

# %%
totpop=pd.read_excel('https://population.un.org/wpp/DVD/Files/2_Indicators%20(Probabilistic%20Projections)/UN_PPP2017_Output_PopTot.xls')

# %%
totpop.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3           Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN                  NaN        NaN
# 1        NaN        NaN        NaN        NaN                  NaN        NaN
# 2        NaN        NaN        NaN        NaN                  NaN        NaN
# 3        NaN        NaN        NaN        NaN       United Nations        NaN
# 4        NaN        NaN        NaN        NaN  Population Division        NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 13  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2         NaN         NaN         NaN         NaN  ...          NaN
# 3         NaN         NaN         NaN         NaN  ...          NaN
# 4         NaN         NaN         NaN         NaN  ...          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "content/drive/My Drive/VideniePresidenta/data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_10576830.csv"
df_bonus = pd.read_excel(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-d3a60e491368> in <module>()
#       1 path = "content/drive/My Drive/VideniePresidenta/data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_10576830.csv"
# ----> 2 df_bonus = pd.read_excel(path)
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...
